# %% [markdown]
# <a href="https://colab.research.google.com/github/Justyasir123/PPE-object-detection/blob/main/PPE_Objects_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PPE Objects Detection Using Computer Vision**

# %% [markdown]
# **This project involves the development of an object detection model to identify Personal Protective Equipment (PPE) such as helmets, gloves, safety vests, and masks using computer vision techniques. The objective is to create a robust system that can detect whether individuals are complying with safety regulations in workplace environments such as construction sites, factories, and laboratories.**

# %% [markdown]
# **Relevance of the Project:**
#
# Ensures workplace safety by detecting proper PPE usage.
#
# Helps in reducing workplace hazards and accidents.
#
# Demonstrates the application of deep learning and computer vision in real-world safety applications.
#
# Enhances students by understanding of machine learning models, image processing, and dataset handling.

# %% [markdown]
# ## 🔧 Step 1: Install YOLOv8 and Required Libraries

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 🚀 Step 2: Train YOLOv8 Model on PPE Detection Dataset

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/PPEDetectionDataset/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## 📈 Step 3: Visualize Training Results
#
# After training is complete, we can view the results including training loss, validation metrics (mAP, precision, recall), and more.

# %%
from IPython.display import display, Image

# Display training results
display(Image(filename='runs/detect/train/results.png'))

# %% [markdown]
# ## ✅ Step 4: Validate the Trained Model on the PPE Detection Dataset
#
# We will now validate the trained YOLOv8 model using the validation set from our PPE Detection Dataset.
# This step helps assess the model's performance using metrics like precision, recall, and mAP.

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=/content/drive/MyDrive/PPEDetectionDataset/data.yaml
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1-4d4XatIdTOGo7KCakXMVZPdz1F3ikYe/PPEDetectionDataset/valid/labels.cache... 420 images, 0 backgrounds, 0 corrupt: 100% 420/420 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 27/27 [00:16<00:00,  1.61it/s]
#                    all        420       1797      0.907      0.884      0.918       0.75
#                  boots        276        593      0.958      0.951      0.981      0.762
#                 gloves         23         41      0.764      0.633      0.687      0.477
#                 helmet        273        320      0.939      0.963      0.978      0.772
#                  human        302        376      0.928      0.934      0.963       0.88
# ...

# %% [markdown]
# ## 🖼️ Step 5: Run Inference on Test Images
#
# We will now use the trained model to detect objects in a sample image from the PPE Detection Dataset.

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/00048_jpg.rf.1b444ed4fa46924c9d227c3865a294ac.jpg
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/00048_jpg.rf.1b444ed4fa46924c9d227c3865a294ac.jpg: 640x640 1 helmet, 2 vests, 62.7ms
# Speed: 3.1ms preprocess, 62.7ms inference, 155.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import display, Image
import glob

# Get the latest predicted image
predicted_image = glob.glob('/content/runs/detect/predict2/00048_jpg.rf.1b444ed4fa46924c9d227c3865a294ac.jpg')[0]

# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/00100_jpg.rf.6db1fdd5b22dce6d02ecd3c5aed754a8.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/00100_jpg.rf.6db1fdd5b22dce6d02ecd3c5aed754a8.jpg: 640x640 2 helmets, 2 vests, 62.6ms
# Speed: 2.9ms preprocess, 62.6ms inference, 169.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import display, Image
import glob

# Get the latest predicted image
predicted_image = glob.glob('/content/runs/detect/predict3/00100_jpg.rf.6db1fdd5b22dce6d02ecd3c5aed754a8.jpg')[0]

# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/image_158_jpg.rf.346fd6e5f9af08e1af5b8a4ca9a72c45.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/image_158_jpg.rf.346fd6e5f9af08e1af5b8a4ca9a72c45.jpg: 640x640 2 bootss, 1 helmet, 1 human, 1 vest, 62.7ms
# Speed: 2.7ms preprocess, 62.7ms inference, 191.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Get the latest predicted image
predicted_image = glob.glob('/content/runs/detect/predict4/image_158_jpg.rf.346fd6e5f9af08e1af5b8a4ca9a72c45.jpg')[0]

# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/Video2_7_jpg.rf.b062d5e03f4cc2eb8393f3303e8f8ed4.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/Video2_7_jpg.rf.b062d5e03f4cc2eb8393f3303e8f8ed4.jpg: 640x640 2 bootss, 1 helmet, 1 human, 1 vest, 62.6ms
# Speed: 2.8ms preprocess, 62.6ms inference, 166.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = glob.glob('/content/runs/detect/predict5/Video2_7_jpg.rf.b062d5e03f4cc2eb8393f3303e8f8ed4.jpg')[0]

# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=!yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/images-2022-07-04T013646-1-_jpg.rf.dbe17cdf87a5e67896ecbcc56a9dba0c.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/images-2022-07-04T013646-1-_jpg.rf.dbe17cdf87a5e67896ecbcc56a9dba0c.jpg: 640x640 2 glovess, 62.6ms
# Speed: 3.0ms preprocess, 62.6ms inference, 157.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = glob.glob('/content/runs/detect/predict6/images-2022-07-04T013646-1-_jpg.rf.dbe17cdf87a5e67896ecbcc56a9dba0c.jpg')[0]



# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=!yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/4843_RolePlay_ConstructionWorker_BoyGirl_jpg.rf.9a5a70b1f94cbcc31a4e4d5470b6b1a4.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/4843_RolePlay_ConstructionWorker_BoyGirl_jpg.rf.9a5a70b1f94cbcc31a4e4d5470b6b1a4.jpg: 640x640 2 helmets, 2 humans, 2 vests, 62.6ms
# Speed: 3.8ms preprocess, 62.6ms inference, 218.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = glob.glob('/content/runs/detect/predict9/4843_RolePlay_ConstructionWorker_BoyGirl_jpg.rf.9a5a70b1f94cbcc31a4e4d5470b6b1a4.jpg')[0]



# Display the image
display(Image(filename=predicted_image))

# %%
# !yolo task=detect mode=predict model=runs/detectrl_jpg.rf.9a5a70b1f94cbcc31a4e4d5470b6b1a4.jpg/train/weights/best.pt source=!yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=/content/drive/MyDrive/PPEDetectionDataset/test/images/ppe_1207_jpg.rf.28fe650cf41d702207c5ac0c93da8313.jpg save=True
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,610,463 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PPEDetectionDataset/test/images/ppe_1207_jpg.rf.28fe650cf41d702207c5ac0c93da8313.jpg: 640x640 4 bootss, 2 helmets, 2 humans, 2 vests, 62.6ms
# Speed: 2.8ms preprocess, 62.6ms inference, 172.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = glob.glob('/content/runs/detect/predict11/ppe_1207_jpg.rf.28fe650cf41d702207c5ac0c93da8313.jpg')[0]



# Display the image
display(Image(filename=predicted_image))
